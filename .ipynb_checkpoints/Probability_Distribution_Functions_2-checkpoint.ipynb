# %% [markdown]
# # Random Variable:
#     A random variable is a set of possible values from a random experiment.
#     ex:- tossing a coin , rolling a dice
#     Random_variable_coin(X) = {H,T},
#     Random_variable_dice(Y) = {1,2,3,4,5,6}
#
#     In probabilty theory these random variable called as sample space.

# %% [markdown]
# # Types of Random Variable
#
# #### Discreate Random Variable
#     This is a Random Variable which can contains the integer value or whole number value.
#     ex: Tossing a coin, rolling the dice:- these outcomes can'nt be like 1.5,1.6
#
# #### Continous Random Variable
#     This is a random variable which can contains the decimal values.
#     ex: Asking cgpa in collge- {9.9,8.5,2.9} this can be in decimal.

# %% [markdown]
# # What is Probability Distribution
#
#     A probability distribution is a list of all of the possible outcomes of a random variable along with
#     their corresponding probability values.
#
#     Problem with Distribution?
#
#     In many scenarios, the number of outcomes can be much larger and hence a table would be tedious to write down.
#     Worse still, the number of possible outcomes could be infinite, in which case, good luck writing a table for that.
#
#     ex: Rolling the 10 dice together, height of student.
#
#     Why are Probability Distributions important?
#
#     Gives an idea about the shape/distribution of the data.
#     And if our data follows a famous distribution then we automatically know a lot about the
#     data.
#
#     A note on Parameters
#     Parameters in probability distributions are numerical values that determine the shape,
#     location, and scale of the distribution.
#
#     Different probability distributions have different sets of parameters that determine their
#     shape and characteristics, and understanding these parameters is essential in statistical
#     analysis and inference.
#
# ** Must Read Notes in Register

# %% [markdown]
# # Probability Distribution Functions
#     A probability distribution function (PDF) is a mathematical function that describes the probability
#     of obtaining different values of a random variable in a particular probability distribution.
#
# #### Types of Probability Distribution functions
#     1) Probability Mass Functions: whenever we use discreate random variable then will plot this graph.
#     2) Probability Density functions: whenever we use continous random variable then will plot this graph.
#
# #### Cumulative distribution functions:
#     with the help and combination of pdf and pmf we will used to plot cdf.

# %% [markdown]
# # Probability Mass Functions
#     PMF stands for Probability Mass Function. It is a mathematical function that describes the probability distribution
#     of a discrete random variable.The PMF of a discrete random variable assigns a probability to each possible value
#     of the random variable. The probabilities assigned by the PMF must satisfy two conditions:
#
#     Here y axis denote the prob and x axis denote the possible outcome
#
#     a). The probability assigned to each value must be non-negative (i.e., greater
#     than or equal to zero).
#     b). The sum of the probabilities assigned to all possible values must equal 1.

# %% [markdown]
# # Probability Mass Functions Practical

# %%
import pandas as pd
import numpy as np
import random

# %%
lst =[]
for i in range(1,10000):
    lst.append(random.randint(1,6))

# %%
lst[:5]
# Out:
# [2, 3, 4, 1, 1]

# %%
# Here we are calculating the probability by calculating the possible no of outcome to the total number of outcome.
prob = (pd.Series(lst).value_counts()/pd.Series(lst).value_counts().sum()).sort_index()
prob
# Out:
# 1    0.168417
# 2    0.167017
# 3    0.158516
# 4    0.172217
# 5    0.168117
# 6    0.165717
# Name: count, dtype: float64

# %%
prob.plot(kind='bar')
# Out:
# <Axes: >

# %%
lst1 = []
for i in range(10000):
    a = random.randint(1,6)
    b = random.randint(1,6)
    lst1.append(a+b)

# %%
prob = (pd.Series(lst1).value_counts()/pd.Series(lst1).value_counts().sum()).sort_index()
prob
# Out:
# 2     0.0283
# 3     0.0542
# 4     0.0840
# 5     0.1077
# 6     0.1350
# 7     0.1633
# 8     0.1444
# 9     0.1183
# 10    0.0795
# 11    0.0558
# 12    0.0295
# Name: count, dtype: float64

# %%
prob.plot(kind='bar')
# Out:
# <Axes: >

# %% [markdown]
# # Convert Cumulative Distribution function to PMF
#
# ### Cumulative distribution functions of PMF
#     The cumulative distribution function (CDF) F(x) describes the probability that a
#     random variable X with a given probability distribution will be found at a value less
#     than or equal to x
#
#     Here y axis denote the prob and x axis denote the possible outcome
#
#     in simple words.
#
#     pmf hame explain karta h x= 5 , x=4 m kya probability h
#     but cdf hame explain karta h x<=5, x<=4 hone ki probability kya h

# %%
cdf = np.cumsum(prob)

# %%
# This graph is telling x ya x se kam hone ka prob.
# 5 ya 5 se kam hone ka prob is 0.3, 9 ya 9 se kam hone ka prob is 0.8
cdf.plot(kind='bar')
# Out:
# <Axes: >

# %% [markdown]
# # Probability Density Function (PDF)
#     PDF stands for Probability Density Function. It is a mathematical function that describes the
#     probability distribution of a continuous random variable.
#
#
#
# #### Why Probability Density and why not Probability?
#
#     We know that there are infinte number lies on the x-axis of the pdf. So we can'nt calcuate the exact probability of
#     any given number so we have to take the probaility density instead of probability.
#     and if we try to calculate the exact prob. then it will return as 0.
#
# #### What does the area represent under the pdf curve?
#     So this will represent the entire prob of all the possible outcome which is basically between 0 <= x <= 10 and
#     if we add up the complete prob value it will give us as 1.
#
#     In this Pdf y-axis is not the probability, area under the curve is the probability, y-axis represent the probability
#     density. and to calculate the probablity we need to integrate the area under the curve with the lower limit and
#     upper limit in integral.
#
#
#
# #### What is probability density?
#
#
# ### Note
#     1) This means that pmf is suitable for studying about the categorical feature in the data where as pdf is used
#     to study about the numerical feature in the data.

# %% [markdown]
# # How is graph calculated?
#
# ## Density Estimation
#
#     Density estimation is a statistical technique used to estimate the probability density function (PDF)
#     of a random variable based on a set of observations or data. In simpler terms,
#     it involves estimating the underlying distribution of a set of data points.
#
#     Density estimation can be used for a variety of purposes, such as hypothesis testing, data analysis,
#     and data visualization. It is particularly useful in areas such as machine learning, where it is often
#     used to estimate the probability distribution of input data or to model the likelihood of certain events or outcomes.
#
#     There are various methods for density estimation, including parametric and nonparametric approaches.
#     Parametric methods assume that the data follows a specific probability distribution
#     (such as a normal distribution), while nonparametric methods do not make any assumptions about the distribution and
#     instead estimate it directly from the data.
#
#     Commonly used techniques for density estimation include kernel density estimation (KDE), histogram estimation,
#     and Gaussian mixture models (GMMs). The choice of method depends on the specific characteristics
#     of the data and the intended use of the density estimate.
#
# ### Types of Density Estimation
#
# #### 1). Parametric Density Estimation
#     Parametric density estimation is a method of estimating the probability density function (PDF) of a
#     random variable by assuming that the underlying distribution belongs to a specific parametric family of
#     probability distributions, such as the normal, exponential, or Poisson distributions.
#
# #### 2) Non-Parametric Density Estimation (KDE)
#
#     But sometimes the distribution is not clear or it's not one of the famous distributions.
#
#     Non-parametric density estimation is a statistical technique used to estimate the probability density function of
#     a random variable without making any assumptions about the underlying distribution. It is also referred
#     to as non-parametric density estimation because it does not require the use of a predefined
#     probability distribution function, as opposed to parametric methods such as the Gaussian distribution.
#
#     The non-parametric density estimation technique involves constructing an estimate of the probability density
#     function using the available DATA. This is typically done by creating a kernel density estimate.
#
#     One of the main advantages is that it does not require the assumption of a specific distribution,
#
#     However, non-parametric density estimation can be computationally intensive and may require more
#     data to achieve accurate estimates compared to parametric methods.

# %% [markdown]
# # Parametric Density Estimation

# %%
import matplotlib.pyplot as plt
import numpy as np 
from numpy.random import normal

# %%
sample = normal(loc=50,scale=5,size = 1000)

# %%
sample.mean()
# Out:
# 49.93561212851653

# %%
# Plot histogram to understand the distribution of data.
plt.hist(sample,bins=10)
# Out:
# (array([ 11.,  39., 132., 221., 251., 210., 101.,  31.,   2.,   2.]),
#  array([35.07470253, 38.46722166, 41.85974079, 45.25225992, 48.64477906,
#         52.03729819, 55.42981732, 58.82233645, 62.21485558, 65.60737472,
#         68.99989385]),
#  <BarContainer object of 10 artists>)

# %%
# With the help of data we have to calculate the sample mean and sample variance
sample_mean = sample.mean()
sample_std = sample.std()
print(sample_mean)
print(sample_std)
# Out:
# 49.93561212851653
# 5.001708149173763

# %%
# Fit the distribution with above parameter like put the value of mean and std in the formula of pdf.
# https://wikimedia.org/api/rest_v1/media/math/render/svg/c9167a4f19898b676d4d1831530a8ff1246d33ab (pdf formula link)
from scipy.stats import norm
dist = norm(sample_mean, sample_std)
type(dist)
# Out:
# scipy.stats._distn_infrastructure.rv_continuous_frozen

# %%
sample.max()
sample.min()
# Out:
# 35.074702527364636

# %%
values = np.linspace(sample.min(),sample.max(),100)
values
# Out:
# array([35.07470253, 35.41738123, 35.76005993, 36.10273863, 36.44541733,
#        36.78809603, 37.13077473, 37.47345343, 37.81613213, 38.15881083,
#        38.50148953, 38.84416823, 39.18684693, 39.52952563, 39.87220433,
#        40.21488303, 40.55756173, 40.90024043, 41.24291913, 41.58559783,
#        41.92827653, 42.27095523, 42.61363393, 42.95631263, 43.29899133,
#        43.64167003, 43.98434873, 44.32702743, 44.66970613, 45.01238483,
#        45.35506353, 45.69774223, 46.04042093, 46.38309963, 46.72577833,
#        47.06845703, 47.41113573, 47.75381443, 48.09649313, 48.43917184,
#        48.78185054, 49.12452924, 49.46720794, 49.80988664, 50.15256534,
#        50.49524404, 50.83792274, 51.18060144, 51.52328014, 51.86595884,
#        52.20863754, 52.55131624, 52.89399494, 53.23667364, 53.57935234,
#        53.92203104, 54.26470974, 54.60738844, 54.95006714, 55.29274584,
#        55.63542454, 55.97810324, 56.32078194, 56.66346064, 57.00613934,
# ...

# %%
probability_density = [dist.pdf(value) for value in values]
probability_density
# Out:
# [0.0009657222080183013,
#  0.0011809693128382458,
#  0.0014374291725230653,
#  0.001741388789247986,
#  0.002099744641602732,
#  0.002519989126547531,
#  0.0030101788490058488,
#  0.003578882010077754,
#  0.004235102338303347,
#  0.004988177344986202,
#  0.005847649176976908,
#  0.006823106995714461,
#  0.007924000629993681,
#  0.009159426223910739,
#  0.010537885713513415,
#  0.012067023188702904,
#  0.013753342493663917,
#  0.015601911742619892,
#  0.0176160617224741,
#  0.01979708635747186,
#  0.022143954456493496,
#  0.024653042782602167,
#  0.027317901010748928,
#  0.030129059312769095,
#  0.03307388907867599,
#  0.036136526613377115,
#  0.03929786851942328,
#  0.04253564589080836,
#  0.0458245824242456,
#  0.04913663915029526,
#  0.052441345767897975,
#  0.05570621562440744,
#  0.058897238329593156,
#  0.06197944095070017,
#  0.06491750583927923,
#  0.0676764305238234,
#  0.070222212894885,
#  0.07252254322871873,
#  0.07454748353997925,
#  0.07627011439684898,
# ...

# %%
plt.hist(sample,bins=10,density=True)
plt.plot(values,probability_density)

# %% [markdown]
# # Kernal Density Estimation
#     The KDE technique involves using a kernel function to smooth out the data and create a
#     continuous estimate of the underlying density function.

# %%
sample1 = normal(loc=20,scale=5,size=300)
sample2 = normal(loc=40,scale=5,size=700)
sample_data = np.hstack((sample1,sample2))

# %%
sample_data
# Out:
# array([20.36275975, 23.5641486 , 14.53397871, 23.78511184, 26.8621626 ,
#        21.87319558, 17.31707943, 10.97796284, 18.05773631, 20.09329585,
#        29.67221742, 22.40262431, 25.91990194, 18.01329228, 27.345223  ,
#        19.14364718, 20.51811625, 19.59177262, 20.72174075,  7.81958218,
#        21.20316313, 24.33903652, 15.99124044, 22.02360515, 25.23821448,
#        29.25772039, 21.95684134, 28.64206495, 17.38547545, 19.08323744,
#        25.99053505, 16.4922875 , 15.28382729, 16.98826217, 30.24134842,
#        18.64732581, 20.28588629, 22.67574745, 13.67244708, 15.08465295,
#         9.98323149, 14.55656109, 13.79635609, 18.37610943, 21.32755871,
#        24.1224315 , 12.79678982, 20.28498783, 22.12137089, 15.00944857,
#        25.59111985, 18.11769259, 17.27989312, 15.98308743, 23.87621973,
#        20.31474541, 20.88753854, 16.78641041, 20.82157998, 20.02072817,
#        14.47227139,  8.63258817, 24.37869312, 25.92448292, 24.40733641,
# ...

# %%
plt.hist(sample_data,bins=50)
plt.show()

# %%
from sklearn.neighbors import KernelDensity
model = KernelDensity(bandwidth=4,kernel='gaussian')
# Convert the data in 2D
sample_data = sample_data.reshape(len(sample_data),1)
model.fit(sample_data)
# Out:
# KernelDensity(bandwidth=4)

# %%
values1 = np.linspace(sample_data.min(),sample_data.max(),100)
values1 = values1.reshape(len(values1),1)
values1
# Out:
# array([[ 4.33275259],
#        [ 4.83572299],
#        [ 5.33869339],
#        [ 5.84166379],
#        [ 6.34463419],
#        [ 6.84760459],
#        [ 7.35057499],
#        [ 7.85354539],
#        [ 8.35651579],
#        [ 8.85948619],
#        [ 9.36245658],
#        [ 9.86542698],
#        [10.36839738],
#        [10.87136778],
#        [11.37433818],
#        [11.87730858],
#        [12.38027898],
#        [12.88324938],
#        [13.38621978],
#        [13.88919017],
#        [14.39216057],
#        [14.89513097],
#        [15.39810137],
#        [15.90107177],
#        [16.40404217],
#        [16.90701257],
#        [17.40998297],
#        [17.91295337],
#        [18.41592376],
#        [18.91889416],
#        [19.42186456],
#        [19.92483496],
#        [20.42780536],
#        [20.93077576],
#        [21.43374616],
#        [21.93671656],
#        [22.43968696],
#        [22.94265735],
#        [23.44562775],
#        [23.94859815],
#        [24.45156855],
# ...

# %%
probabilities = model.score_samples(values1)
probabilities = np.exp(probabilities)
probabilities
# score_samples(values) returns the log-density estimate of the input samples values. 
# This is because the score_samples() method of the KernelDensity class 
# returns the logarithm of the probability density estimate rather than the actual probability density estimate.
# Out:
# array([0.00106443, 0.00127517, 0.00151953, 0.00180116, 0.00212362,
#        0.00249031, 0.00290427, 0.00336799, 0.0038832 , 0.00445072,
#        0.00507024, 0.00574019, 0.00645761, 0.00721809, 0.0080158 ,
#        0.00884351, 0.00969272, 0.01055389, 0.0114166 , 0.01226985,
#        0.01310236, 0.01390284, 0.01466037, 0.0153646 , 0.01600615,
#        0.01657681, 0.01706978, 0.01747997, 0.01780406, 0.01804074,
#        0.01819076, 0.01825696, 0.01824429, 0.01815977, 0.01801232,
#        0.01781268, 0.01757318, 0.01730751, 0.01703051, 0.01675789,
#        0.01650592, 0.01629121, 0.0161303 , 0.01603941, 0.01603406,
#        0.01612873, 0.01633644, 0.01666841, 0.01713363, 0.01773852,
#        0.0184866 , 0.0193782 , 0.02041025, 0.02157621, 0.022866  ,
#        0.02426608, 0.0257597 , 0.02732708, 0.02894586, 0.03059145,
#        0.03223756, 0.03385673, 0.03542086, 0.03690186, 0.03827225,
#        0.03950576, 0.04057802, 0.04146712, 0.04215427, 0.04262421,
# ...

# %%
plt.hist(sample_data,bins=50,density=True)
plt.plot(values1[:],probabilities)
plt.show()

# %% [markdown]
# # Cumulative Distribution Function(CDF) of PDF
#     In cdf y-axis represent the probability.
#     pdf represent what is the probability density at x= 165 and cdf gives us the probability at x<=165.
#     In pdf, if we apply integration and find area under the curve then will get cdf and if we apply diffrentiation
#     on cdf then will get the pdf again.

# %%
import seaborn as sns

# %%
df = sns.load_dataset('iris')

# %%
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
sns.kdeplot(data=df , x='sepal_length',hue='species')
# Out:
# <Axes: xlabel='sepal_length', ylabel='Density'>

# %%
sns.kdeplot(data=df , x='sepal_width',hue='species')
# Out:
# <Axes: xlabel='sepal_width', ylabel='Density'>

# %%
sns.kdeplot(data=df , x='petal_length',hue='species')
# Out:
# <Axes: xlabel='petal_length', ylabel='Density'>

# %%
sns.kdeplot(data=df , x='petal_width',hue='species')
# Out:
# <Axes: xlabel='petal_width', ylabel='Density'>

# %%
titanic_data = pd.read_csv(r"C:\Users\sasha\Desktop\Statistics CX\DataSet\titanic.csv")
titanic_data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
sns.kdeplot(data=titanic_data,x='Age',hue='Survived')
# Out:
# <Axes: xlabel='Age', ylabel='Density'>

# %%
sns.kdeplot(data=df , x='petal_width',hue='species')
sns.ecdfplot(data=df,x='petal_width',hue='species')
# With the help of cdf we are able to decide how much percent our model is accurate.
# For versicolor
# We can see on x-axis it intersect the two curve at 1.7 and we can see clealy on y-axis that its probability of 
# getting the versiocolor is 95%. that mean our model will be accurate 95 percent time.
#  Same we can do it in different case.
# Out:
# <Axes: xlabel='petal_width', ylabel='Density'>

# %% [markdown]
# # 2D density plot

# %%
# This graph is showing how the two numerical columns which is petal_length and sepal_length are related.
sns.jointplot(data=df,x='petal_length',y='sepal_length',kind='kde',fill=True,cbar=True)
